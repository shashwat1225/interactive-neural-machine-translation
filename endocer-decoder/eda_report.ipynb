# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from tqdm import tqdm
from collections import Counter

# %%
import nltk
from wordcloud import WordCloud

# %%
# load the dataset
train_source_text_path = "../data/sup_train.en-fr.fr"
train_target_text_path = "../data/sup_train.en-fr.en"
dev_source_text_path = "../data/sup_valid.en-fr.fr"
dev_target_text_path = "../data/sup_valid.en-fr.en"
test_source_text_path = "../data/test.en-fr.fr"
test_target_text_path = "../data/test.en-fr.en"

# %%
# read the data from the files and store them in pandas dataframe
def retrieve_data(file_path):
    data = []
    with open(file_path, 'r') as f:
        for line in f.readlines():
            line = line.strip()
            data.append(line)
    return data

# %%
train_source_sentences = retrieve_data(train_source_text_path)
train_target_sentences = retrieve_data(train_target_text_path)

# %%
train_source_sentences = train_source_sentences[:len(train_source_sentences)//2]
train_target_sentences = train_target_sentences[:len(train_target_sentences)//2]

# %%
len(train_source_sentences), len(train_target_sentences)
# Out:
# (783196, 783196)

# %%
zipped_train_data = list(zip(train_source_sentences, train_target_sentences))

# %%
train_data = pd.DataFrame(zipped_train_data, columns=['source', 'target'])

# %%
pd.set_option('display.max_colwidth', None)
train_data.head()
# Out:
#                                                                                                                                                                                                                                                           source  \
# 0                                                                                                                                                                                                                                          reprise de la session
# 1                                                          je déclare reprise la session du parlement européen qui avait été interrompue le vendredi 17 décembre dernier et je vous renouvelle tous mes vux en espérant que vous avez passé de bonnes vacances .
# 2                            comme vous avez pu le constater , le grand " bogue de l' an 2000 " ne s' est pas produit . en revanche , les citoyens d' un certain nombre de nos pays ont été victimes de catastrophes naturelles qui ont vraiment été terribles .
# 3                                                                                                                                                       vous avez souhaité un débat à ce sujet dans les prochains jours , au cours de cette période de session .
# 4  en attendant , je souhaiterais , comme un certain nombre de collègues me l' ont demandé , que nous observions une minute de silence pour toutes les victimes , des tempêtes notamment , dans les différents pays de l' union européenne qui ont été touchés .
#
#                                                                                                                                                                                                                                             target
# 0                                                                                                                                                                                                                        resumption of the session
# 1                                i declare resumed the session of the european parliament adjourned on friday 17 december 1999 , and i would like once again to wish you a happy new year in the hope that you enjoyed a pleasant festive period .
# 2                                            although , as you will have seen , the dreaded ' millennium bug ' failed to materialise , still the people in a number of countries suffered a series of natural disasters that truly were dreadful .
# 3                                                                                                                                      you have requested a debate on this subject in the course of the next few days , during this part-session .
# 4  in the meantime , i should like to observe a minute ' s silence , as a number of members have requested , on behalf of all the victims concerned , particularly those of the terrible storms , in the various countries of the european union .

# %%
train_data['src_length'] = train_data['source'].map(lambda text: len(text))
train_data.head()
# Out:
#                                                                                                                                                                                                                                                           source  \
# 0                                                                                                                                                                                                                                          reprise de la session
# 1                                                          je déclare reprise la session du parlement européen qui avait été interrompue le vendredi 17 décembre dernier et je vous renouvelle tous mes vux en espérant que vous avez passé de bonnes vacances .
# 2                            comme vous avez pu le constater , le grand " bogue de l' an 2000 " ne s' est pas produit . en revanche , les citoyens d' un certain nombre de nos pays ont été victimes de catastrophes naturelles qui ont vraiment été terribles .
# 3                                                                                                                                                       vous avez souhaité un débat à ce sujet dans les prochains jours , au cours de cette période de session .
# 4  en attendant , je souhaiterais , comme un certain nombre de collègues me l' ont demandé , que nous observions une minute de silence pour toutes les victimes , des tempêtes notamment , dans les différents pays de l' union européenne qui ont été touchés .
#
#                                                                                                                                                                                                                                             target  \
# 0                                                                                                                                                                                                                        resumption of the session
# 1                                i declare resumed the session of the european parliament adjourned on friday 17 december 1999 , and i would like once again to wish you a happy new year in the hope that you enjoyed a pleasant festive period .
# 2                                            although , as you will have seen , the dreaded ' millennium bug ' failed to materialise , still the people in a number of countries suffered a series of natural disasters that truly were dreadful .
# 3                                                                                                                                      you have requested a debate on this subject in the course of the next few days , during this part-session .
# 4  in the meantime , i should like to observe a minute ' s silence , as a number of members have requested , on behalf of all the victims concerned , particularly those of the terrible storms , in the various countries of the european union .
#
#    src_length
# 0          21
# 1         197
# 2         227
# 3         104
# 4         253

# %%
train_data['target_length'] = train_data['target'].map(lambda text: len(text))
train_data.head()
# Out:
#                                                                                                                                                                                                                                                           source  \
# 0                                                                                                                                                                                                                                          reprise de la session
# 1                                                          je déclare reprise la session du parlement européen qui avait été interrompue le vendredi 17 décembre dernier et je vous renouvelle tous mes vux en espérant que vous avez passé de bonnes vacances .
# 2                            comme vous avez pu le constater , le grand " bogue de l' an 2000 " ne s' est pas produit . en revanche , les citoyens d' un certain nombre de nos pays ont été victimes de catastrophes naturelles qui ont vraiment été terribles .
# 3                                                                                                                                                       vous avez souhaité un débat à ce sujet dans les prochains jours , au cours de cette période de session .
# 4  en attendant , je souhaiterais , comme un certain nombre de collègues me l' ont demandé , que nous observions une minute de silence pour toutes les victimes , des tempêtes notamment , dans les différents pays de l' union européenne qui ont été touchés .
#
#                                                                                                                                                                                                                                             target  \
# 0                                                                                                                                                                                                                        resumption of the session
# 1                                i declare resumed the session of the european parliament adjourned on friday 17 december 1999 , and i would like once again to wish you a happy new year in the hope that you enjoyed a pleasant festive period .
# 2                                            although , as you will have seen , the dreaded ' millennium bug ' failed to materialise , still the people in a number of countries suffered a series of natural disasters that truly were dreadful .
# 3                                                                                                                                      you have requested a debate on this subject in the course of the next few days , during this part-session .
# 4  in the meantime , i should like to observe a minute ' s silence , as a number of members have requested , on behalf of all the victims concerned , particularly those of the terrible storms , in the various countries of the european union .
#
#    src_length  target_length
# 0          21             25
# 1         197            209
# 2         227            197
# 3         104            107
# 4         253            239

# %%
src_text_length = train_data.src_length.values
src_mean_length = np.mean(src_text_length)
print ("The average length of a source sentence is: %s" % (src_mean_length))

target_text_length = train_data.target_length.values
target_mean_length = np.mean(target_text_length)
print ("The average length of a target sentence is: %s" % (target_mean_length))

mean_lens = [src_mean_length, target_mean_length]
# create a dataset
bars = ('source (French)', 'target (English)')
x_pos = np.arange(len(bars))

# Create bars with different colors
#plt.bar(x_pos, mean_lens, color=['green', 'blue'])
sns.set_style("whitegrid", {'axes.grid': False, 'axes.facecolor': '#efefef'})
colors = ['#E26461', '#88B3AE']
sns.barplot(x=x_pos, y=mean_lens, palette=colors)


# Create names on the x-axis
plt.xticks(x_pos, bars)

# plt.xlabel('x% of words as partial translation')
plt.ylabel('Average sentence length')
plt.title("Comparison of average length of source (French) and target (English) training sentence")

# Show graph
plt.show()
# Out:
# The average length of a source sentence is: 176.18480942190715
# The average length of a target sentence is: 156.829088759391

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.gca()
# Look at the distribution of the data
ax = sns.histplot(x=src_text_length, bins=40, ax=ax, kde=False)
ax.axvline(src_mean_length, lw=4, ls='dashed', color='black')
ax.set(xlabel='French Sentence Length')
ax.set(ylabel='Count')
plt.xticks(range(0,1000,100))
plt.yticks(range(0,100000,10000))
plt.title("Histogram for French Sentence Length")

plt.show()

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.gca()
# Look at the distribution of the data
ax = sns.histplot(x=target_text_length, bins=40, ax=ax, kde=False)
ax.axvline(target_mean_length, lw=4, ls='dashed', color='black')
ax.set(xlabel='English Sentence Length')
ax.set(ylabel='Count')
plt.xticks(range(0,1000,100))
plt.yticks(range(0,100000,10000))
plt.title("Histogram for English Sentence Length")
plt.show()

# %%
# Tokenize the corpus
train_data['source_tokenized'] = train_data['source'].apply(nltk.word_tokenize)

# %%
train_data['source_tokenized'].head()
# Out:
# 0                           [reprise, de, la, session]
# 1    [je, déclare, reprise, la, session, du, parlem...
# 2    [comme, vous, avez, pu, le, constater, ,, le, ...
# 3    [vous, avez, souhaité, un, débat, à, ce, sujet...
# 4    [en, attendant, ,, je, souhaiterais, ,, comme,...
# Name: source_tokenized, dtype: object

# %%
# Count the frequency of each token
fdist = nltk.FreqDist()

for sent in train_data['source']:
    for word in nltk.word_tokenize(sent):
        fdist[word.lower()] += 1

# %%
fdist.plot(20, c='#6b8e99')
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
last_twenty = dict(fdist.most_common()[-20:])

# %%
fdist.most_common()[-20:].plot()
# Out:
# {'inter-universités': 1,
#  'levitine': 1,
#  'khordorkovsky': 1,
#  'woody': 1,
#  'judoka': 1,
#  'foute': 1,
#  'antirusse': 1,
#  'instaurerons': 1,
#  'nazarbayev': 1,
#  'ues': 1,
#  'fripouille': 1,
#  'approvisionnée': 1,
#  'tokaji': 1,
#  'bolchevique-communiste': 1,
#  'hertzen': 1,
#  'bukovski': 1,
#  'mésentente': 1,
#  'théodose': 1,
#  'dissidences': 1,
#  'modernisatrices': 1}

# %%
# Count the frequency of each token
fdist_target = nltk.FreqDist()

for sent in train_data['target']:
    for word in nltk.word_tokenize(sent):
        fdist_target[word.lower()] += 1

# %%
fdist_target.plot(20, c='#6b8e99')
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
last_twenty_target = dict(fdist_target.most_common()[-20:])

# %%
last_twenty_target
# Out:
# {'self-aggrandising': 1,
#  'costume': 1,
#  'fortressed': 1,
#  'beguile': 1,
#  '1776': 1,
#  'mini-constitution': 1,
#  'russia-european': 1,
#  'khodorkovski': 1,
#  'khordorkovsky': 1,
#  'jaunts': 1,
#  'judoka': 1,
#  'russophobic': 1,
#  'no-less-pragmatic': 1,
#  'near-abroad': 1,
#  'tokaji': 1,
#  'bolshevik-communist': 1,
#  'hertzen': 1,
#  'bukovski': 1,
#  'import-related': 1,
#  'theodosius': 1}

# %%
# Load text data from file
# Generate a word cloud from the text
wordcloud = WordCloud(background_color='white', width=800, height=600).generate(train_source_sentences)

# Plot the word cloud
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 # Load text data from file
#       2 # Generate a word cloud from the text
# ----> 3 wordcloud = WordCloud(background_color='white', width=800, height=600).generate(train_source_sentences)
#       5 # Plot the word cloud
#       6 plt.imshow(wordcloud, interpolation='bilinear')
#
# File ~/conda/envs/py310/lib/python3.10/site-packages/wordcloud/wordcloud.py:639, in WordCloud.generate(self, text)
#     624 def generate(self, text):
#     625     """Generate wordcloud from text.
#     626
#     627     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     637     self
#     638     """
# --> 639     return self.generate_from_text(text)
#
# File ~/conda/envs/py310/lib/python3.10/site-packages/wordcloud/wordcloud.py:620, in WordCloud.generate_from_text(self, text)
#     603 def generate_from_text(self, text):
#     604     """Generate wordcloud from text.
#     605
#     606     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     618     self
#     619     """
# --> 620     words = self.process_text(text)
#     621     self.generate_from_frequencies(words)
#     622     return self
#
# File ~/conda/envs/py310/lib/python3.10/site-packages/wordcloud/wordcloud.py:582, in WordCloud.process_text(self, text)
#     579 pattern = r"\w[\w']*" if self.min_word_length <= 1 else r"\w[\w']+"
#     580 regexp = self.regexp if self.regexp is not None else pattern
# --> 582 words = re.findall(regexp, text, flags)
#     583 # remove 's
#     584 words = [word[:-2] if word.lower().endswith("'s") else word
#     585          for word in words]
#
# File ~/conda/envs/py310/lib/python3.10/re.py:240, in findall(pattern, string, flags)
#     232 def findall(pattern, string, flags=0):
#     233     """Return a list of all non-overlapping matches in the string.
#     234
#     235     If one or more capturing groups are present in the pattern, return
#    (...)
#     238
#     239     Empty matches are included in the result."""
# --> 240     return _compile(pattern, flags).findall(string)
#
# TypeError: expected string or bytes-like object
